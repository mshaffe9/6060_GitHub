# %% [markdown]
# # CA-01

# %% [markdown]
# ### Purpose: predict listing price for sellers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://github.com/ArinB/MSBA-CA-Data/raw/main/CA01/house-price-train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# # Data Understanding

# %% [markdown]
# ### Univariate, Bivariate & Multivariate Analysis
# ### Exploration & Visualization

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# ...

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %% [markdown]
# ### Graphical representation of columns

# %%
# visualize the distribution of a numeric column
plt.hist(df['MSSubClass'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['LotArea'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['LotFrontage'])
plt.show()

# %%
# visualize the distribution of a categorical column
df['MSZoning'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['Street'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# **Not much variability in this column**

# %%
# visualize the distribution of a categorical column
df['Alley'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['LotShape'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['LandContour'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['Utilities'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# **Not much variability in this column**

# %%
# visualize the distribution of a categorical column
df['LotConfig'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['LandSlope'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['Neighborhood'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['Condition1'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['Condition2'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# **Not much variability in this column**

# %%
# visualize the distribution of a categorical column
df['BldgType'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['HouseStyle'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['OverallQual'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['OverallCond'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['YearBuilt'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['YearRemodAdd'])
plt.show()

# %%
# visualize the distribution of a categorical column
df['RoofStyle'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['RoofMatl'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# **Not much variability in this column**

# %%
# visualize the distribution of a categorical column
df['Exterior1st'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['Exterior2nd'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['MasVnrType'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['MasVnrArea'])
plt.show()

# %%
# visualize the distribution of a categorical column
df['ExterQual'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['ExterCond'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['Foundation'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['BsmtQual'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['BsmtCond'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['BsmtExposure'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['BsmtFinType1'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['BsmtFinSF1'])
plt.show()

# %%
# visualize the distribution of a categorical column
df['BsmtFinType2'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['BsmtFinSF2'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['BsmtUnfSF'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['TotalBsmtSF'])
plt.show()

# %%
# visualize the distribution of a categorical column
df['Heating'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# **Not much variability in this column**

# %%
# visualize the distribution of a categorical column
df['HeatingQC'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['CentralAir'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['Electrical'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['1stFlrSF'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['2ndFlrSF'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['LowQualFinSF'])
plt.show()

# %% [markdown]
# **Not much variability in this column**

# %%
# visualize the distribution of a numeric column
plt.hist(df['GrLivArea'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['BsmtFullBath'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['BsmtHalfBath'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['FullBath'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['HalfBath'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['BedroomAbvGr'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['KitchenAbvGr'])
plt.show()

# %%
# visualize the distribution of a categorical column
df['KitchenQual'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['TotRmsAbvGrd'])
plt.show()

# %%
# visualize the distribution of a categorical column
df['Functional'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['Fireplaces'])
plt.show()

# %%
# visualize the distribution of a categorical column
df['FireplaceQu'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['GarageYrBlt'])
plt.show()

# %%
# visualize the distribution of a categorical column
df['GarageFinish'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['GarageType'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['GarageCars'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['GarageArea'])
plt.show()

# %%
# visualize the distribution of a categorical column
df['GarageQual'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['GarageCond'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['PavedDrive'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['WoodDeckSF'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['OpenPorchSF'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['EnclosedPorch'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['3SsnPorch'])
plt.show()

# %% [markdown]
# **Not much variability in this column**

# %%
# visualize the distribution of a numeric column
plt.hist(df['ScreenPorch'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['PoolArea'])
plt.show()

# %% [markdown]
# **Not much variability in this column**

# %%
# visualize the distribution of a numeric column
plt.hist(df['MiscVal'])
plt.show()

# %% [markdown]
# **Not much variability in this column**

# %%
# visualize the distribution of a numeric column
plt.hist(df['MoSold'])
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['YrSold'])
plt.show()

# %%
# visualize the distribution of a categorical column
df['SaleType'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a categorical column
df['SaleCondition'].value_counts().plot(kind='bar')
plt.show()

# %%
# visualize the distribution of a numeric column
plt.hist(df['SalePrice'])
plt.show()

# %% [markdown]
# **That was a lot of graphs. Some of them seemed to be unimportant to what we are trying to predict, which is the list price of homes in this dataset. Other graphs indicated that there was not a lot of variation within the feature, which raised suspicion that these features were not imperative to predicting list price.**

# %% [markdown]
# **Below are a few basic stats that outline a skeleton of the Data Quality Report. This process could be run for each individual column to give data scientists a deeper look into the data.**

# %%
# calculate basic statistics for a numeric column
print(df['MSSubClass'].describe())
# Out:
# count    1460.000000
# mean       56.897260
# std        42.300571
# min        20.000000
# 25%        20.000000
# 50%        50.000000
# 75%        70.000000
# max       190.000000
# Name: MSSubClass, dtype: float64

# %%
# calculate basic statistics for a categorical column
print(df['Alley'].describe())
# Out:
# count       91
# unique       2
# top       Grvl
# freq        50
# Name: Alley, dtype: object

# %% [markdown]
# **This feature seems to be missing a lot of data.**

# %%
# calculate basic statistics for a numeric column
print(df['LotArea'].describe())
# Out:
# count      1460.000000
# mean      10516.828082
# std        9981.264932
# min        1300.000000
# 25%        7553.500000
# 50%        9478.500000
# 75%       11601.500000
# max      215245.000000
# Name: LotArea, dtype: float64

# %%
# calculate basic statistics for a numeric column
print(df['FullBath'].describe())
# Out:
# count    1460.000000
# mean        1.565068
# std         0.550916
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         2.000000
# max         3.000000
# Name: FullBath, dtype: float64

# %%
# calculate basic statistics for a numeric column
print(df['SalePrice'].describe())
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
# calculate basic statistics for a numeric column
print(df['OverallQual'].describe())
# Out:
# count    1460.000000
# mean        6.099315
# std         1.382997
# min         1.000000
# 25%         5.000000
# 50%         6.000000
# 75%         7.000000
# max        10.000000
# Name: OverallQual, dtype: float64

# %% [markdown]
# **Based on the basic statistics per the Data Quality Report, there could be outliers in the MSSubClass, LotArea, and SalePrice columns.**

# %%
# create a pairplot to visualize the relationships between multiple numeric columns
sns.pairplot(df, vars=['SalePrice', '1stFlrSF'])
plt.show()

# %% [markdown]
# **It looks like SalePrice and 1stFlrSF are strongly correlated.**

# %% [markdown]
# **Overall, this process of understanding the data is helpful to get a sense of which features to keep or remove and gives light to other problems in the dataset, such as outliers or missing data within each column.**

# %% [markdown]
# # Pre-Processing

# %% [markdown]
# **Handle missing values,
# encoding,
# IDness,
# handle outliers,
# normalization and scaling,
# stability and health checks**

# %%
pd.set_option('display.max_rows', None)

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
df1 = df.copy()

# %%
#Delete columns Alley PoolQC, Fence, MiscFeature because they had most values missing and/or 
#weren't deemed as important to predict listing price
df1.drop(columns=['Alley','PoolQC','Fence','MiscFeature','LotFrontage','FireplaceQu'], inplace=True)

# %%
df1.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotArea           0
# Street            0
# LotShape          0
# LandContour       0
# Utilities         0
# LotConfig         0
# LandSlope         0
# Neighborhood      0
# Condition1        0
# Condition2        0
# BldgType          0
# HouseStyle        0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# YearRemodAdd      0
# RoofStyle         0
# RoofMatl          0
# Exterior1st       0
# Exterior2nd       0
# MasVnrType        8
# MasVnrArea        8
# ExterQual         0
# ExterCond         0
# Foundation        0
# BsmtQual         37
# BsmtCond         37
# BsmtExposure     38
# BsmtFinType1     37
# BsmtFinSF1        0
# BsmtFinType2     38
# BsmtFinSF2        0
# BsmtUnfSF         0
# TotalBsmtSF       0
# Heating           0
# HeatingQC         0
# CentralAir        0
# Electrical        1
# 1stFlrSF          0
# 2ndFlrSF          0
# LowQualFinSF      0
# GrLivArea         0
# ...

# %%
#dropped the rest of the NA values because there were not many compared to the entire dataset
#and the values within these columns not deemed important to predicting list price
df1.dropna(inplace=True)
df1.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# ...

# %% [markdown]
# **Drop Duplicates**

# %%
df1 = df1.drop_duplicates()
df1.shape
# Out:
# (1338, 70)

# %%
# encode categorical variables using one-hot encoding
df1 = pd.get_dummies(df1, columns=['Street', 'CentralAir', 'PavedDrive'], prefix=['Street', 'CentralAir', 'PavedDrive'])

# %% [markdown]
# **Outliers**

# %%
from scipy.stats import zscore
df1['zscore_SalePrice'] = zscore(df1['SalePrice'])

# %%
threshold = 2
df1['outliers'] = np.where((df1['zscore_SalePrice'] - threshold > 0), True, np.where(df1['zscore_SalePrice'] + threshold < 0, True, False))

# %%
df1.drop(df1[df1['outliers'] == True].index,inplace=True)

# %% [markdown]
# **Standardization**

# %%
# standardize the values of a numeric column
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df1['LotArea'] = scaler.fit_transform(df1[['LotArea']])

# %%
# standardize the values of a numeric column
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df1['LotArea'] = scaler.fit_transform(df1[['MSSubClass']])

# %% [markdown]
# **Use StandardScaler to have distribution mean value 0 and standard deviation of 1. This will help with the outliers identified previously.**

# %%
# calculate summary statistics for a numeric column
print(df1['1stFlrSF'].describe())
# Out:
# count    1338.000000
# mean     1176.221973
# std       386.644986
# min       438.000000
# 25%       894.000000
# 50%      1098.000000
# 75%      1414.000000
# max      4692.000000
# Name: 1stFlrSF, dtype: float64

# %%
# calculate summary statistics for a numeric column
print(df1['2ndFlrSF'].describe())
# Out:
# count    1338.000000
# mean      357.141256
# std       440.324982
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       740.500000
# max      2065.000000
# Name: 2ndFlrSF, dtype: float64

# %%
# apply a robust scaling to a numeric column
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
df1['1stFlrSF'] = scaler.fit_transform(df1[['1stFlrSF']])

# %%
# apply a robust scaling to a numeric column
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
df1['2ndFlrSF'] = scaler.fit_transform(df1[['2ndFlrSF']])

# %%
# calculate the skewness and kurtosis of a numeric column
print(df1['SalePrice'].skew())
print(df1['SalePrice'].kurtosis())
# Out:
# 1.9436856448420148
# 6.815307479336196

# %%
# perform a t-test to compare the means of two numeric columns
from scipy.stats import ttest_ind

t, p = ttest_ind(df1['SalePrice'], df1['1stFlrSF'])
print(t, p)
# Out:
# 86.56901938632524 0.0

# %%
# perform an ANOVA test to compare the means of two or more numeric columns
from scipy.stats import f_oneway

f, p = f_oneway(df1['SalePrice'], df1['1stFlrSF'])
print(f, p)
# Out:
# 7494.195117509955 0.0

# %%
# calculate the correlation between two numeric columns
print(df1['SalePrice'].corr(df1['1stFlrSF']))
# Out:
# 0.604714484629278

# %% [markdown]
# # Post Processing

# %% [markdown]
# ### Feature Selection
# ### Collinearity

# %%
#Feature Selection: Delete columns because based on above graphs, they had little variation within dataset
df1.drop(columns=['Id','Utilities','Condition2','RoofMatl','Heating','LowQualFinSF','3SsnPorch','PoolArea','MiscVal'], inplace=True)

# %%
# create a heatmap to visualize the correlation between multiple columns
plt.figure(figsize=(30, 20))
sns.heatmap(df1.corr(), cmap='RdYlGn', annot=True)
plt.show()

# %% [markdown]
# There may be collinearity in features that are highly correlated (above 0.6 or below -0.6) to one another.
# Besides SalePrice (because this is the dependent variable we are trying to predict), these features include OverallQual, TotalBsmtSF, 1stFlrSF, GrLivArea, GarageCars, GarageArea, Street_Grvl, Street_Pave, CentralAir_N, CentralAir_Y, PavedDrive_N, PavedDrive_Y, YearBuilt, YearRemodAdd, TotRmsAbvGrd, 2ndFlrSF, BedroomAbvGrd, HalfBath, FullBath. We may consider deleting the columns listed above in our future analysis.

# %% [markdown]
# # Conclusion

# %% [markdown]
# It is clear that the EDA process can be very dense. In order to have analytics ready data, most datasets require a lot of cleaning and preparing which takes time and resources. The dataset that I have tried to clean and prepare in this assignment is by no means a perfect dataset, and may never be perfect.
#
# Understanding the data took a lot of time because I wanted to visualize every single column...that's 81 columns. It may have been tedious and a waste of time, but since this was my first time analyzing data in this way, it was helpful to get a visual for each feature and get a better sense of the story behind the data. If I had more time, I would have delved further into the Data Quality Report basic statistics section. I found this to be interesting because you were able to predict which columns might have outliers and may need standardization or normalization. There are also so many other visualizations to explore such as violin plots, scatter plots, box plots, etc. however, it was difficult to know which ones to use for each feature. Again, if I had more time, I would try to implement a variety of graphs/charts that could represent my data better.
#
# The Data Pre-Processing section consisted of dropping columns, dropping NA values, dropping outliers, dropping duplicates, standardization, normalization, and running multiple tests on the data. Ultimately, this was the big data clean-up section. I used my insights from Understanding the data to know which columns to drop, which columns might have outliers, and which columns to standardize. Since the dataset was so large and I was limited on time, I know that I did not fully clean it up. I would like to know more about when to use the different types of standardization and/or normalization techniques, the t-test, and the ANOVA test.
#
# For Data Post-Processing, I only used Feature Selection and Collinearity. Based on my insights from previous analysis, I found a few more columns to delete that did not add value to trying to predict the list price. Lastly, the heat map showed the correlation between columns. The heat map boxes that have greater than 0.6 or less than -0.6 are considered to be dependent on another variable. For the purpose of trying to predict the list price, it would be important to delete the columns that are dependent on other variables so that only independent variables are being used in our data. This would hopefully give a more accurate result about which features impact the list price.
#
# Overall, this was a great learning experience to introduce me to the process of EDA. As frustrating as it was sometimes, it opened my eyes to how vast the world of Machine Learning is...and it seems I barely touched the surface of it! I am genuinely curious to
